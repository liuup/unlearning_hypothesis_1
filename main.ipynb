# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import Subset, DataLoader, TensorDataset

import torchvision
import torchvision.transforms as transforms

import time
import copy
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
import wandb
wandb.init(
    # set the wandb project where this run will be logged
    project="hypothesis",
    config={
    "architecture": "CNN",
    "dataset": "CIFAR-10",
    }
)
# Out:
# Finishing last run (ID:yndks4p3) before initializing another...
# VBox(children=(Label(value='0.005 MB of 0.005 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>model1_base_cnn.0.weight</td><td>███▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>model1_base_cnn.10.weight</td><td>██▇▇▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>model1_base_cnn.13.weight</td><td>█▇▇▆▆▅▅▅▅▅▅▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>model1_base_cnn.3.weight</td><td>██▇▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>model1_base_cnn.6.weight</td><td>█▇▇▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>model1base_cossim</td><td>██▇▇▆▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>model2_base_cnn.0.weight</td><td>███▇▇▇▇▆▆▆▅▅▅▅▅▅▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>model2_base_cnn.10.weight</td><td>██▇▇▆▆▅▅▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>model2_base_cnn.13.weight</td><td>█▇▇▇▆▆▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>model2_base_cnn.3.weight</td><td>█▇▇▇▆▆▆▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>model2_base_cnn.6.weight</td><td>█▇▆▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>model2base_cossim</td><td>██▇▇▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>model_1_train_loss</td><td>█▇▇▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>model_1_val_correct</td><td>▁▂▃▃▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇████████████████████</td></tr><tr><td>model_1_val_loss</td><td>█▇▆▆▅▄▄▃▃▃▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂</td></tr><tr><td>model_2_train_loss</td><td>█▇▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>model_2_val_correct</td><td>▁▂▄▄▅▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇████████████████████</td></tr><tr><td>model_2_val_loss</td><td>█▇▆▅▅▄▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>63</td></tr><tr><td>model1_base_cnn.0.weight</td><td>0.88324</td></tr><tr><td>model1_base_cnn.10.weight</td><td>0.40868</td></tr><tr><td>model1_base_cnn.13.weight</td><td>0.75278</td></tr><tr><td>model1_base_cnn.3.weight</td><td>0.59107</td></tr><tr><td>model1_base_cnn.6.weight</td><td>0.58608</td></tr><tr><td>model1base_cossim</td><td>0.50097</td></tr><tr><td>model2_base_cnn.0.weight</td><td>0.88904</td></tr><tr><td>model2_base_cnn.10.weight</td><td>0.39402</td></tr><tr><td>model2_base_cnn.13.weight</td><td>0.73176</td></tr><tr><td>model2_base_cnn.3.weight</td><td>0.58985</td></tr><tr><td>model2_base_cnn.6.weight</td><td>0.57515</td></tr><tr><td>model2base_cossim</td><td>0.48824</td></tr><tr><td>model_1_train_loss</td><td>0.25857</td></tr><tr><td>model_1_val_correct</td><td>0.7547</td></tr><tr><td>model_1_val_loss</td><td>0.8888</td></tr><tr><td>model_2_train_loss</td><td>0.29996</td></tr><tr><td>model_2_val_correct</td><td>0.7549</td></tr><tr><td>model_2_val_loss</td><td>0.88828</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">grateful-bee-24</strong> at: <a href='https://wandb.ai/akaabel/hypothesis/runs/yndks4p3' target="_blank">https://wandb.ai/akaabel/hypothesis/runs/yndks4p3</a><br/> View project at: <a href='https://wandb.ai/akaabel/hypothesis' target="_blank">https://wandb.ai/akaabel/hypothesis</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240922_224849-yndks4p3/logs</code>
# Successfully finished last run (ID:yndks4p3). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011128234266652725, max=1.0…
# Tracking run with wandb version 0.18.1
# Run data is saved locally in <code>/Users/up/Desktop/Data/unlearning_hypothesis_1/wandb/run-20240922_231100-ai7rkzxo</code>
# Syncing run <strong><a href='https://wandb.ai/akaabel/hypothesis/runs/ai7rkzxo' target="_blank">giddy-moon-25</a></strong> to <a href='https://wandb.ai/akaabel/hypothesis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/akaabel/hypothesis' target="_blank">https://wandb.ai/akaabel/hypothesis</a>
#  View run at <a href='https://wandb.ai/akaabel/hypothesis/runs/ai7rkzxo' target="_blank">https://wandb.ai/akaabel/hypothesis/runs/ai7rkzxo</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/akaabel/hypothesis/runs/ai7rkzxo?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# Machine unlearning fails to remove data poisoning attacks
#
# 假设1：毒害样本在训练时会导致比较大的模型偏移，并且用unlearning算法无法纠正
#
# 因此设置实验来验证到底造成了多少的模型偏移
#
# 1. 使用两个相同的初始模型，m1，m2
# 2. 在m1上用正常数据集上训练x个epoch
# 3. 在m2上有毒害样本的数据集上训练x个epoch
# 4. 同时对两个模型训练，训练时，测量模型间距离（余弦相似度，KL散度）和模型的层之间距离
#
# 毒害数据的生成：
# 1. 在图片中加入固定位置 固定大小的水印，标签不变
# 2. 比例需要确定一下，比如1.5%...?

# %%
# import visdom
# # 初始化一个visdom可视化
# visdom = visdom.Visdom(env="main")

# %%
batch_size = 64
ratio = 0.1 # 控制抽取的百分比比例
alpha = 0.5  # 控制融合的比例，比例越高，原始图片的信息越多


transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
cifar10_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=False, transform=transform)
validate_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=False, transform=transform)

num_samples = len(cifar10_dataset)

subset_size = int(ratio * num_samples)
all_indices = list(range(num_samples))
random.shuffle(all_indices)
subset_indices = all_indices[:subset_size]   # 指定比例的数据索引
remaining_indices = all_indices[subset_size:]  # 剩下数据的索引

# 按照抽取的索引创建子集
subset_dataset = Subset(cifar10_dataset, subset_indices)

fusion_image = Image.open('hellokitty.png').resize((32, 32))
fusion_image = transforms.ToTensor()(fusion_image)

fused_images = []
fused_labels = []

# 对每张图片进行融合
for img, label in DataLoader(subset_dataset, batch_size=1):
    img_fused = alpha * img + (1 - alpha) * fusion_image.unsqueeze(0)
    # img_fused = img_fused.clamp(0, 1)
    fused_images.append(img_fused.squeeze(0))
    fused_labels.append(label)

fused_images = torch.stack(fused_images)
fused_labels = torch.tensor(fused_labels).squeeze()

# 创建包含融合图片的数据集
fused_dataset = TensorDataset(fused_images, fused_labels)

# 剩余的数据集
remaining_dataset = Subset(cifar10_dataset, remaining_indices)

# 合并剩余数据和融合图片后的数据
remaining_loader = DataLoader(remaining_dataset, batch_size=len(remaining_dataset), shuffle=False)
remaining_images, remaining_labels = next(iter(remaining_loader))

# 合并所有数据
final_images = torch.cat((remaining_images, fused_images), dim=0)
final_labels = torch.cat((remaining_labels, fused_labels), dim=0)

# 加载到新的数据集
final_dataset = TensorDataset(final_images, final_labels)


#
# 构造dataloader
#

# 只包含毒性数据的dataloader，只用来做可视化测试，不参与训练和验证
only_posion_loader = DataLoader(fused_dataset, batch_size=batch_size, shuffle=True)

# 正常数据
benign_trainloader = DataLoader(remaining_dataset, batch_size=batch_size, shuffle=True)

# 正常数据 + 包含固定比例的毒害数据
poison_trainloader = DataLoader(final_dataset, batch_size=batch_size, shuffle=True)

# 正常数据，用于验证
valloader = DataLoader(validate_dataset, batch_size=batch_size, shuffle=False)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

print(len(only_posion_loader.dataset))
print(len(benign_trainloader.dataset))
print(len(poison_trainloader.dataset))
print(len(valloader.dataset))
# Out:
# 5000
# 45000
# 50000
# 10000

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(only_posion_loader)
images, _ = next(dataiter)
imshow(torchvision.utils.make_grid(images))

dataiter = iter(poison_trainloader)
images, _ = next(dataiter)
imshow(torchvision.utils.make_grid(images))

# print labels
# print(' '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))

# %%
computing_device = "mps"

class CNN(nn.Module):
    def __init__(self, *args, **kwargs) -> None:
        super().__init__(*args, **kwargs)
        # self.cnn = nn.Sequential(
        #     nn.Conv2d(3, 6, 5),
        #     nn.ReLU(),
        #     nn.MaxPool2d(2, 2),

        #     nn.Conv2d(6, 16, 5),
        #     nn.ReLU(),
        #     nn.MaxPool2d(2, 2),

        #     nn.Flatten(),
        #     nn.Linear(16 * 5 * 5, 256),
        #     nn.ReLU(),
        #     nn.Dropout(0.3),
        #     nn.Linear(256, 128),
        #     nn.ReLU(),
        #     nn.Linear(128, 10),
        #     nn.Sigmoid(),
        # )

        self.cnn = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Flatten(),
            nn.Linear(128 * 4 * 4, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, 10),
        )

    def forward(self, x):
        return self.cnn(x)

# %%
# resnet = torchvision.models.resnet18(num_classes=10)
# temp = torch.randn([32, 3, 32, 32])
# print(resnet(temp).size())

# %%
lr = 0.0001
lambda_value = 0.001

# 基准模型，不参与训练
base_model = CNN().to(computing_device)

# 模型在正常数据集上训练
model1 = copy.deepcopy(base_model)
loss_fn1 = nn.CrossEntropyLoss()
optimizer1 = torch.optim.Adam(model1.parameters(), lr=lr, weight_decay=lambda_value)

# 模型在正常数据集+异常数据上训练
model2 = copy.deepcopy(base_model)
loss_fn2 = nn.CrossEntropyLoss()
optimizer2 = torch.optim.Adam(model2.parameters(), lr=lr, weight_decay=lambda_value)

# 模型在正常数据+毒害数据上训练
# model3 = copy.deepcopy(base_model)
# loss_fn3 = nn.CrossEntropyLoss()
# optimizer3 = torch.optim.SGD(model3.parameters(), lr=lr)

print(sum(p.numel() for p in base_model.parameters()))   # 查看一下模型参数量
# Out:
# 620362

# %%
# model1在正常数据上训练，model2在正常+毒害上训练
dataloaders = [benign_trainloader, poison_trainloader]

models = [model1, model2]
loss_fns = [loss_fn1, loss_fn2]
optimizers = [optimizer1, optimizer2]

# 添加一下 模型的权重层名称 只添加weight 不添加bias
model_layers = []
for k in model1.state_dict():
    if k.find("bias") >= 1:
        continue
    model_layers.append(k)
print(model_layers)
# Out:
# ['cnn.0.weight', 'cnn.3.weight', 'cnn.6.weight', 'cnn.10.weight', 'cnn.13.weight']

# %%
# 随便挑一个数据查看一下输入输出维度
tmpdata = torch.randn([1, 1, 1])
for X, y in valloader:
    # print(X.size())
    # print(y.size())
    print(y)
    tmpdata = X.to(computing_device)
    break

y = y.to(computing_device)
print(tmpdata.size())
res = model1(tmpdata)

# print(res.size())

print(res.argmax(1))
print(y)
print((res.argmax(1) == y).type(torch.float).sum().item() )
# Out:
# tensor([3, 8, 8, 0, 6, 6, 1, 6, 3, 1, 0, 9, 5, 7, 9, 8, 5, 7, 8, 6, 7, 0, 4, 9,
#         5, 2, 4, 0, 9, 6, 6, 5, 4, 5, 9, 2, 4, 1, 9, 5, 4, 6, 5, 6, 0, 9, 3, 9,
#         7, 6, 9, 8, 0, 3, 8, 8, 7, 7, 4, 6, 7, 3, 6, 3])
# torch.Size([64, 3, 32, 32])
# tensor([6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#         6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6,
#         6, 6, 6, 6, 6, 6, 0, 6, 6, 6, 6, 6, 6, 6, 6, 6], device='mps:0')
# tensor([3, 8, 8, 0, 6, 6, 1, 6, 3, 1, 0, 9, 5, 7, 9, 8, 5, 7, 8, 6, 7, 0, 4, 9,
#         5, 2, 4, 0, 9, 6, 6, 5, 4, 5, 9, 2, 4, 1, 9, 5, 4, 6, 5, 6, 0, 9, 3, 9,
#         7, 6, 9, 8, 0, 3, 8, 8, 7, 7, 4, 6, 7, 3, 6, 3], device='mps:0')
# 11.0

# %%
# 训练
def train_model(epoch, model, loss_fn, optimizer, trainloader):
    # training
    num_batches = len(trainloader)
    model.train()
    train_loss = 0
    for batch, (X, y) in enumerate(trainloader):
        X, y = X.to(computing_device), y.to(computing_device)

        predict = model(X)

        loss = loss_fn(predict, y)
        train_loss += loss.item()

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    train_loss /= num_batches

    return train_loss

# 验证
def val_model(epoch, model, loss_fn, valloader):
    size = len(valloader.dataset)
    num_batches = len(valloader)
    
    model.eval()
    test_loss, val_correct = 0, 0
    with torch.no_grad():        
        for batch, (X, y) in enumerate(valloader):
            X, y = X.to(computing_device), y.to(computing_device)

            predict = model(X)
            loss = loss_fn(predict, y)
            test_loss += loss.item()
            val_correct += (predict.argmax(1) == y).type(torch.float).sum().item() 
            
    test_loss /= num_batches
    val_correct /= size

    return test_loss, val_correct

# 测试
def test_model(model, loss_fn, testloader):
    pass

# %%
# train_loss_list = [[], []]
# val_loss_list = [[], []]

# # 模型间相似度 刚开始两个相同的模型间肯定是1
# model_cossim_list = [1]

# # 层间相似度
# layer_cossim_list = []
# for idx, _ in enumerate(model_layers):
#     layer_cossim_list.append([1])

# %%
start_epoch = 0 # 从哪一个epoch开始
num_epochs = 32 # 要训练多少个epoch

# time_all = 0    # 消耗的总时长，单位s

for epoch in range(start_epoch, start_epoch + num_epochs):
    # size = len(testloader.dataset)

    print(f"Epoch {epoch}")
    # 训练多个模型
    for idx, _ in enumerate(models):
        wandb.log({"epoch": epoch})


        ts = time.perf_counter() # 打一个时间戳

        train_loss = train_model(epoch, models[idx], loss_fns[idx], optimizers[idx], dataloaders[idx])
        val_loss, val_correct = val_model(epoch, models[idx], loss_fns[idx], valloader)

        td = time.perf_counter()    # 打一个时间戳
        # time_all += (td - ts)

        print(f"Model {idx+1} | TrainLoss {train_loss:.5f} | ValLoss {val_loss:.5f} | ValCorrect {val_correct:.5f}| EpochTime {(td - ts):.5f}s")
        # wandb.log({"model_name": f"model_{idx}", "train_loss": train_loss, "val_loss": val_loss})
        wandb.log({f"model_{idx+1}_train_loss": train_loss, f"model_{idx+1}_val_loss": val_loss, f"model_{idx+1}_val_correct": val_correct})

        # visdom.line(np.array([train_loss]), np.array([epoch]), win=f"Model {idx} Train Loss", update="append", opts={"title": f"Model {idx} Train Loss"})
        # visdom.line(np.array([val_loss]), np.array([epoch]), win=f"Model {idx} Val Loss", update="append", opts={"title": f"Model {idx} Val Loss"})

    # 测量model1和base_model的余弦相似度距离
    # 测量model2和base_model的余弦相似度距离
    model_base_params = torch.cat([p.view(-1) for p in base_model.parameters()])
    model_tmp1_params = torch.cat([p.view(-1) for p in model1.parameters()])
    model_tmp2_params = torch.cat([p.view(-1) for p in model2.parameters()])

    model1base_cossim = F.cosine_similarity(model_base_params.unsqueeze(0), model_tmp1_params.unsqueeze(0)).item()
    model2base_cossim = F.cosine_similarity(model_base_params.unsqueeze(0), model_tmp2_params.unsqueeze(0)).item()

    print(f"model1base_cossim: {model1base_cossim}, model2base_cossim: {model2base_cossim}")
    wandb.log({"model1base_cossim": model1base_cossim, "model2base_cossim": model2base_cossim})
    

    # 测量model1与base_model之间层的相似度
    for idx, k, in enumerate(model_layers):
        tensor_base = base_model.state_dict()[k].flatten()
        tensor_tmp = model1.state_dict()[k].flatten()
        layer_cos_sim = F.cosine_similarity(tensor_base.unsqueeze(0), tensor_tmp.unsqueeze(0)).item()
        
        # print(f"Model 1 and base, {k}, {layer_cos_sim}")
        wandb.log({f"model1_base_{k}": layer_cos_sim})

    # 测量model2与base_model之间层的相似度
    for idx, k, in enumerate(model_layers):
        tensor_base = base_model.state_dict()[k].flatten()
        tensor_tmp = model2.state_dict()[k].flatten()
        layer_cos_sim = F.cosine_similarity(tensor_base.unsqueeze(0), tensor_tmp.unsqueeze(0)).item()
        
        # print(f"Model 2 and base, {k}, {layer_cos_sim}")
        wandb.log({f"model2_base_{k}": layer_cos_sim})

    # print(f"Epoch: {epoch} | TrainLoss: {train_loss:.5f} | ValLoss: {test_loss:.5f} | EpochTime: {(td - ts):.5f}s ｜ TimeRemaining: {(time_all / (epoch - start_epoch + 1)) * (start_epoch + num_epochs - epoch - 1):.5f}s")
    print("----- ----- ----- ----- -----")
# Out:
# Epoch 0
# Model 1 | TrainLoss 1.84186 | ValLoss 1.57098 | ValCorrect 0.42170| EpochTime 6.87936s
# Model 2 | TrainLoss 1.85697 | ValLoss 1.55633 | ValCorrect 0.43160| EpochTime 4.67467s
# model1base_cossim: 0.8633700609207153, model2base_cossim: 0.8513414859771729
# ----- ----- ----- ----- -----
# Epoch 1
# Model 1 | TrainLoss 1.54860 | ValLoss 1.43227 | ValCorrect 0.48410| EpochTime 6.74915s
# Model 2 | TrainLoss 1.56915 | ValLoss 1.42491 | ValCorrect 0.48250| EpochTime 4.80121s
# model1base_cossim: 0.8090820908546448, model2base_cossim: 0.795191764831543
# ----- ----- ----- ----- -----
# Epoch 2
# Model 1 | TrainLoss 1.44936 | ValLoss 1.34410 | ValCorrect 0.51110| EpochTime 6.81732s
# Model 2 | TrainLoss 1.46494 | ValLoss 1.33489 | ValCorrect 0.51380| EpochTime 4.72407s
# model1base_cossim: 0.7711907029151917, model2base_cossim: 0.757705807685852
# ----- ----- ----- ----- -----
# Epoch 3
# Model 1 | TrainLoss 1.37541 | ValLoss 1.28290 | ValCorrect 0.53320| EpochTime 6.75752s
# Model 2 | TrainLoss 1.39764 | ValLoss 1.29461 | ValCorrect 0.53300| EpochTime 4.73075s
# model1base_cossim: 0.7413167953491211, model2base_cossim: 0.7282291650772095
# ----- ----- ----- ----- -----
# Epoch 4
# Model 1 | TrainLoss 1.31366 | ValLoss 1.23399 | ValCorrect 0.55850| EpochTime 6.74070s
# Model 2 | TrainLoss 1.33603 | ValLoss 1.24649 | ValCorrect 0.54940| EpochTime 4.76584s
# model1base_cossim: 0.7156519889831543, model2base_cossim: 0.7020409107208252
# ----- ----- ----- ----- -----
# Epoch 5
# Model 1 | TrainLoss 1.26521 | ValLoss 1.18879 | ValCorrect 0.57450| EpochTime 6.86372s
# Model 2 | TrainLoss 1.28934 | ValLoss 1.19098 | ValCorrect 0.57390| EpochTime 4.79786s
# model1base_cossim: 0.6923861503601074, model2base_cossim: 0.6787641644477844
# ----- ----- ----- ----- -----
# Epoch 6
# Model 1 | TrainLoss 1.21537 | ValLoss 1.14583 | ValCorrect 0.58760| EpochTime 6.82590s
# Model 2 | TrainLoss 1.24364 | ValLoss 1.17627 | ValCorrect 0.57760| EpochTime 4.73488s
# model1base_cossim: 0.6712803840637207, model2base_cossim: 0.6570868492126465
# ----- ----- ----- ----- -----
# Epoch 7
# Model 1 | TrainLoss 1.17465 | ValLoss 1.11372 | ValCorrect 0.60250| EpochTime 6.82473s
# Model 2 | TrainLoss 1.20573 | ValLoss 1.12082 | ValCorrect 0.59900| EpochTime 4.72005s
# model1base_cossim: 0.6528545618057251, model2base_cossim: 0.6378079652786255
# ----- ----- ----- ----- -----
# Epoch 8
# Model 1 | TrainLoss 1.13799 | ValLoss 1.10056 | ValCorrect 0.60780| EpochTime 6.77348s
# Model 2 | TrainLoss 1.16586 | ValLoss 1.08373 | ValCorrect 0.61330| EpochTime 4.78531s
# model1base_cossim: 0.6357074975967407, model2base_cossim: 0.6201949119567871
# ----- ----- ----- ----- -----
# Epoch 9
# Model 1 | TrainLoss 1.10416 | ValLoss 1.08107 | ValCorrect 0.60830| EpochTime 6.73985s
# Model 2 | TrainLoss 1.13374 | ValLoss 1.06404 | ValCorrect 0.62010| EpochTime 4.79211s
# model1base_cossim: 0.619628369808197, model2base_cossim: 0.603739321231842
# ----- ----- ----- ----- -----
# Epoch 10
# Model 1 | TrainLoss 1.07525 | ValLoss 1.02474 | ValCorrect 0.63720| EpochTime 6.74809s
# Model 2 | TrainLoss 1.10539 | ValLoss 1.02499 | ValCorrect 0.63490| EpochTime 4.78324s
# model1base_cossim: 0.6049932241439819, model2base_cossim: 0.5882675647735596
# ----- ----- ----- ----- -----
# Epoch 11
# Model 1 | TrainLoss 1.04224 | ValLoss 1.01071 | ValCorrect 0.64370| EpochTime 6.80550s
# Model 2 | TrainLoss 1.07678 | ValLoss 1.01800 | ValCorrect 0.64080| EpochTime 5.70117s
# model1base_cossim: 0.5907453894615173, model2base_cossim: 0.5738290548324585
# ----- ----- ----- ----- -----
# Epoch 12
# Model 1 | TrainLoss 1.01712 | ValLoss 0.98239 | ValCorrect 0.65520| EpochTime 7.08520s
# Model 2 | TrainLoss 1.04514 | ValLoss 1.01177 | ValCorrect 0.63760| EpochTime 4.90246s
# model1base_cossim: 0.5777102708816528, model2base_cossim: 0.5603762865066528
# ----- ----- ----- ----- -----
# Epoch 13
# Model 1 | TrainLoss 0.98902 | ValLoss 0.97979 | ValCorrect 0.65240| EpochTime 8.28765s
# Model 2 | TrainLoss 1.01839 | ValLoss 0.97200 | ValCorrect 0.65980| EpochTime 5.13985s
# model1base_cossim: 0.5655487775802612, model2base_cossim: 0.5476795434951782
# ----- ----- ----- ----- -----
# Epoch 14
# Model 1 | TrainLoss 0.96858 | ValLoss 0.96111 | ValCorrect 0.66460| EpochTime 6.96394s
# Model 2 | TrainLoss 0.99416 | ValLoss 0.94115 | ValCorrect 0.67200| EpochTime 4.96936s
# model1base_cossim: 0.554061233997345, model2base_cossim: 0.5356922149658203
# ----- ----- ----- ----- -----
# Epoch 15
# Model 1 | TrainLoss 0.94409 | ValLoss 0.93175 | ValCorrect 0.67620| EpochTime 7.10916s
# Model 2 | TrainLoss 0.97097 | ValLoss 0.92288 | ValCorrect 0.67730| EpochTime 4.84204s
# model1base_cossim: 0.5430166721343994, model2base_cossim: 0.5244143605232239
# ----- ----- ----- ----- -----
# Epoch 16
# Model 1 | TrainLoss 0.91918 | ValLoss 0.95025 | ValCorrect 0.66790| EpochTime 6.99046s
# Model 2 | TrainLoss 0.94969 | ValLoss 0.90697 | ValCorrect 0.68360| EpochTime 4.97377s
# model1base_cossim: 0.5324816703796387, model2base_cossim: 0.5136101245880127
# ----- ----- ----- ----- -----
# Epoch 17
# Model 1 | TrainLoss 0.89767 | ValLoss 0.91030 | ValCorrect 0.68570| EpochTime 6.69070s
# Model 2 | TrainLoss 0.92895 | ValLoss 0.90511 | ValCorrect 0.68420| EpochTime 4.51463s
# model1base_cossim: 0.522472620010376, model2base_cossim: 0.5035993456840515
# ----- ----- ----- ----- -----
# Epoch 18
# Model 1 | TrainLoss 0.88195 | ValLoss 0.88963 | ValCorrect 0.69270| EpochTime 6.61955s
# Model 2 | TrainLoss 0.90792 | ValLoss 0.89658 | ValCorrect 0.68430| EpochTime 4.50005s
# model1base_cossim: 0.5130716562271118, model2base_cossim: 0.4939935803413391
# ----- ----- ----- ----- -----
# Epoch 19
# Model 1 | TrainLoss 0.86117 | ValLoss 0.87145 | ValCorrect 0.69480| EpochTime 6.59741s
# Model 2 | TrainLoss 0.89051 | ValLoss 0.88822 | ValCorrect 0.68850| EpochTime 5.18094s
# model1base_cossim: 0.5041318535804749, model2base_cossim: 0.48496508598327637
# ----- ----- ----- ----- -----
# Epoch 20
# Model 1 | TrainLoss 0.83985 | ValLoss 0.85598 | ValCorrect 0.70440| EpochTime 6.91581s
# Model 2 | TrainLoss 0.87040 | ValLoss 0.86544 | ValCorrect 0.69740| EpochTime 4.80413s
# model1base_cossim: 0.49541282653808594, model2base_cossim: 0.47617030143737793
# ----- ----- ----- ----- -----
# Epoch 21
# Model 1 | TrainLoss 0.82462 | ValLoss 0.86385 | ValCorrect 0.69990| EpochTime 6.80624s
# Model 2 | TrainLoss 0.85352 | ValLoss 0.84756 | ValCorrect 0.70470| EpochTime 4.64823s
# model1base_cossim: 0.48724254965782166, model2base_cossim: 0.4680138826370239
# ----- ----- ----- ----- -----
# Epoch 22
# Model 1 | TrainLoss 0.80921 | ValLoss 0.84835 | ValCorrect 0.70560| EpochTime 6.68958s
# Model 2 | TrainLoss 0.83581 | ValLoss 0.84309 | ValCorrect 0.70480| EpochTime 4.62769s
# model1base_cossim: 0.4793999195098877, model2base_cossim: 0.4601788818836212
# ----- ----- ----- ----- -----
# Epoch 23
# Model 1 | TrainLoss 0.79527 | ValLoss 0.83049 | ValCorrect 0.71170| EpochTime 6.67363s
# Model 2 | TrainLoss 0.81949 | ValLoss 0.83939 | ValCorrect 0.70690| EpochTime 4.57997s
# model1base_cossim: 0.47191348671913147, model2base_cossim: 0.45270824432373047
# ----- ----- ----- ----- -----
# Epoch 24
# Model 1 | TrainLoss 0.77634 | ValLoss 0.82729 | ValCorrect 0.71050| EpochTime 6.68251s
# Model 2 | TrainLoss 0.80260 | ValLoss 0.83945 | ValCorrect 0.70700| EpochTime 4.63599s
# model1base_cossim: 0.46461838483810425, model2base_cossim: 0.44557392597198486
# ----- ----- ----- ----- -----
# Epoch 25
# Model 1 | TrainLoss 0.75704 | ValLoss 0.82068 | ValCorrect 0.71520| EpochTime 6.68237s
# Model 2 | TrainLoss 0.78590 | ValLoss 0.81771 | ValCorrect 0.71760| EpochTime 4.63300s
# model1base_cossim: 0.4577392339706421, model2base_cossim: 0.43863850831985474
# ----- ----- ----- ----- -----
# Epoch 26
# Model 1 | TrainLoss 0.74228 | ValLoss 0.80853 | ValCorrect 0.71830| EpochTime 6.68756s
# Model 2 | TrainLoss 0.77377 | ValLoss 0.81856 | ValCorrect 0.71650| EpochTime 4.63406s
# model1base_cossim: 0.45109423995018005, model2base_cossim: 0.43197691440582275
# ----- ----- ----- ----- -----
# Epoch 27
# Model 1 | TrainLoss 0.72862 | ValLoss 0.79833 | ValCorrect 0.72130| EpochTime 6.70250s
# Model 2 | TrainLoss 0.75737 | ValLoss 0.80191 | ValCorrect 0.72160| EpochTime 4.59789s
# model1base_cossim: 0.44459861516952515, model2base_cossim: 0.42583322525024414
# ----- ----- ----- ----- -----
# Epoch 28
# Model 1 | TrainLoss 0.71547 | ValLoss 0.79727 | ValCorrect 0.72430| EpochTime 6.68515s
# Model 2 | TrainLoss 0.74409 | ValLoss 0.81231 | ValCorrect 0.71770| EpochTime 4.63086s
# model1base_cossim: 0.4385625123977661, model2base_cossim: 0.4197603762149811
# ----- ----- ----- ----- -----
# Epoch 29
# Model 1 | TrainLoss 0.70043 | ValLoss 0.79369 | ValCorrect 0.72490| EpochTime 6.75043s
# Model 2 | TrainLoss 0.72664 | ValLoss 0.80147 | ValCorrect 0.72500| EpochTime 4.62213s
# model1base_cossim: 0.4326801002025604, model2base_cossim: 0.41377633810043335
# ----- ----- ----- ----- -----
# Epoch 30
# Model 1 | TrainLoss 0.68520 | ValLoss 0.78600 | ValCorrect 0.72500| EpochTime 6.88189s
# Model 2 | TrainLoss 0.71508 | ValLoss 0.79977 | ValCorrect 0.72180| EpochTime 4.74704s
# model1base_cossim: 0.42697370052337646, model2base_cossim: 0.4082506597042084
# ----- ----- ----- ----- -----
# Epoch 31
# Model 1 | TrainLoss 0.67206 | ValLoss 0.79411 | ValCorrect 0.72050| EpochTime 6.78145s
# Model 2 | TrainLoss 0.70425 | ValLoss 0.77259 | ValCorrect 0.73330| EpochTime 4.57950s
# model1base_cossim: 0.421494722366333, model2base_cossim: 0.4028252363204956
# ----- ----- ----- ----- -----

# %%
# train_loss_list = [[], []]
# test_loss_list = [[], []]

# # 模型间相似度 刚开始两个相同的模型间肯定是1
# model_cossim_list = [1]

# # 层之间相似度
# layer_cossim_list = []
# for idx, _ in enumerate(model_layers):
#     layer_cossim_list.append([1])

# %%
# print(train_loss_list)
# print(test_loss_list)
# print(model_cossim_list)
# print(layer_cossim_list)

# %%
# model 1 train_loss

# x = range(len(train_loss_list[0]))
# plt.figure(dpi=200)
# plt.plot(x, train_loss_list[0])
# plt.xticks(np.arange(min(x), max(x) + 1, 1))  # 设置 x 轴只显示整数 从最小值到最大值，步长为1
# plt.title('Model 1 Train Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Train Loss')
# plt.show()

# %%
# # model 2 train_loss

# x = range(len(train_loss_list[1]))
# plt.figure(dpi=200)
# plt.plot(x, train_loss_list[1])
# plt.xticks(np.arange(min(x), max(x) + 1, 1))  # 设置 x 轴只显示整数 从最小值到最大值，步长为1
# plt.title('Model 2 Train Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Train Loss')
# plt.show()

# %%
# # model 1 test_loss

# x = range(len(test_loss_list[0]))
# plt.figure(dpi=200)
# plt.plot(x, test_loss_list[0])
# plt.xticks(np.arange(min(x), max(x) + 1, 1))  # 设置 x 轴只显示整数 从最小值到最大值，步长为1
# plt.title('Model 1 Test Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Train Loss')
# plt.show()

# %%
# # model 2 test_loss

# x = range(len(test_loss_list[1]))
# plt.figure(dpi=200)
# plt.plot(x, test_loss_list[1])
# plt.xticks(np.arange(min(x), max(x) + 1, 1))  # 设置 x 轴只显示整数 从最小值到最大值，步长为1
# plt.title('Model 2 Test Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Train Loss')
# plt.show()

# %%
# # layer
# x = range(len(layer_cossim_list[0]))
# lines = []
# plt.figure(dpi=200)
# for idx, layer in enumerate(layer_cossim_list):
#     plt.plot(x, layer, label=model_layers[idx])

# plt.plot(x, model_cossim_list, label="model", marker='o')

# plt.xticks(np.arange(min(x), max(x) + 1, 1))  # 设置 x 轴只显示整数 从最小值到最大值，步长为1
# plt.title("Layer Cos Sim")
# plt.xlabel('Epoch')
# plt.ylabel('Cos Sim')
# plt.legend()
# plt.show()

# %%
# for k in model1.state_dict():
#     # print(type(k))
#     # print(k)
#     # break
#     if k.find("bias") >= 1:
#         continue
#     print(k)

# %%
# print(model.state_dict()["stack.0.weight"].size())
# print(model.state_dict()["stack.2.weight"].size())
# print(model.state_dict()["stack.5.weight"].size())
# print(model.state_dict()["stack.7.weight"].size())
# print(model.state_dict()["stack.9.weight"].size())

# %%
tmp1 = model1.state_dict()["stack.0.weight"]
tmp1 = tmp1.flatten()
print(tmp1.size())

tmp2 = model2.state_dict()["stack.0.weight"]
tmp2 = tmp2.flatten()
print(tmp2.size())

cos_sim = F.cosine_similarity(tmp1.unsqueeze(0), tmp2.unsqueeze(0))

print(cos_sim.item())

# %%
model1_params = torch.cat([p.view(-1) for p in model1.parameters()])
model2_params = torch.cat([p.view(-1) for p in model2.parameters()])
model_cos_sim = F.cosine_similarity(model1_params.unsqueeze(0), model2_params.unsqueeze(0))
print(f"Model, CosSim {model_cos_sim.item()}")
